# %%
def user_info(name ="test" ,age =20):
    """
    this function take name and age from user and return it again
    :param_1:take the name of user from input user interface
    type param_1:str
    :param_2:take the age of user from input user interface
    type param_2:int
    
    return :this function will print the name and the age 
    rtype:str , int 
    """
    return f"my name is {name} , my age is {age}"

# %%
user_info()
# Out:
# 'my name is test , my age is 20'

# %%
def user_info(*name):
    print(name)
    print(type(name))

# %%
user_info("Depi","python",5,2.5,True,[1,2,3])
# Out:
# ('Depi', 'python', 5, 2.5, True, [1, 2, 3])
# <class 'tuple'>

# %%
x="Shenouda"
y=90
"{0},{1}".format(x,y)
# Out:
# 'rahma,90'

# %%
def user_info(**name):
    print(name)
    print(type(name))
user_info(key1=10.5,key2=2)
# Out:
# {'key1': 10.5, 'key2': 2}
# <class 'dict'>

# %%
from user_info import user_info
user_info
# Out:
# <function user_info.user_info(name='test', age=20)>

# %%
result =lambda x:x+10
print(result(10))
# Out:
# 20

# %%
function_name= lambda x,y:x+y
print(function_name(5,10))
# Out:
# 15

# %%
function_name= lambda x,y,z:x+y*z
print(function_name(5,10,2))
# Out:
# 25

# %%
x=30

# %%
global x=20

def fun(age):
    print("inside ",x)
fun(x)
print("outside",x)
# Out:
# inside  20
# outside 20

# %%
x="global"
def outer_fun():
    x="outer_local"
    def inner_fun():
        global x
        x="changed"
        print("inside inner fun",x)
    inner_fun()
    print("inside outer func: ",x)
outer_fun()
print("outside any func: ",x)
# Out:
# inside inner fun changed
# inside outer func:  outer_local
# outside any func:  changed

# %%
try:
    5/0
except:
    print("not allow to divode by zero")
# Out:
# not allow to divode by zero

# %%
x = int(input())
y= int(input())
try:
    x/y
except:
    print("not allow to divode by zero")
# Out:
# not allow to divode by zero

# %%
x = int(input())
y= int(input())
try:
    x/y
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
x = int(input())
y= int(input())
try:
    x/y
except Exception as e:
    print(" ",e)

# %%
try:
    x=10
    y=int (input())
    x/y
except:
    print("division by zero")
finally:
    print("done")
# Out:
# division by zero
# done

# %%
from random import randint, random
randint(0,10)
# Out:
# 1

# %%
from random import randint, random
random()
# Out:
# 0.8663911496928922

# %%
import os

# %%
base_dire="C:/Users/Test/Desktop/DEPI-ONL4_AIS2_S2/python-for-ml/session3/code/file_handling"

# %%
type(base_dire)
# Out:
# str

# %%
file_names= os.listdir(base_dire)
type(file_names)
file_names
# Out:
# ['test.txt']

# %%
import os
dir="C:\\Users\\sheno\\Downloads\\DEBI-ONL4_AIS2_S2\\Python_For_ML\\session3\\code\\Shenouda_Safwat"
if not os.path.exists(dir):
    os.makedirs(dir)
else:
    print("exist")

# %%
import os
dir="C:\\Users\\sheno\\Downloads\\DEBI-ONL4_AIS2_S2\\Python_For_ML\\session3\\code\\Shenouda_Safwat"
# if not os.path.exists(dir):
#     os.makedirs(dir)
for i in range(20):
    inner_path= os.path.join(dir,"dir_"+str(i))
    if not os.path.exists(inner_path):
        os.makedirs(inner_path)
